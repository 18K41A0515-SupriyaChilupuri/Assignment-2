# %%
 a = float(input('Enter Length1: '))
 b = float(input('Enter Length2: '))
 c = float(input('Enter Length3: '))
s = (a + b + c) / 2


area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print("The area of the triangle is :",round(area,3))
# Out:
# Enter Length1: 5
# Enter Length2: 6
# Enter Length3: 7
# The area of the triangle is : 14.697
