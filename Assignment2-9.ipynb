# %%
a = int(input("Enter first integer: "))
b = int(input("Enter second integer: "))
c = int(input("Enter third integer: "))
a1 = min(a, b, c)
a3 = max(a, b, c)
a2 = (a + b + c) - a1 - a3
print("Numbers in sorted order are: ", a1, a2, a3)
# Out:
# Enter first integer: 56
# Enter second integer: 62
# Enter third integer: 10
# Numbers in sorted order are:  10 56 62
