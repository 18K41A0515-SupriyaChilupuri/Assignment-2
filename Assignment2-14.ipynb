# %%
#Write a Python code that takes a number and returns a list of its digits. 
#So for  input: 586392 it should return
#output: [5,8,6,3,9,2] 
  
num=input("Enter number")
print (str(num)) 
res = [int(x) for x in str(num)] 
print (str(res))
# Out:
# Enter number586392
# 586392
# [5, 8, 6, 3, 9, 2]
